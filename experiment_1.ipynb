# %%
#Experiment 1 - Introduction to python
#Naman Bothra
#PRN - 25070123078

x = "apple" ; y = "orange" ;  z = "cherry"
print(x,y,z,sep = "\n")
# Out:
# apple
# orange
# cherry

# %%
x,y,z,w = 2,2.5,"Naman",True
print(type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a = 10 ; b = 5
print("add=",a+b,"\n","sub=",a-b,"\n","mult=",a*b,"\n","div=",a/b,"\n","exp=",a**b)
# Out:
# add= 15
#  sub= 5
#  mult= 50
#  div= 2.0
#  exp= 100000

# %%
a = int(input("Enter a value of a: ",))
b = int(input("Enter a value of b: "))
print("add=",a+b,"\n","sub=",a-b,"\n","mult=",a*b,"\n","div=",a/b,"\n","exp=",a**b)
# Out:
# Enter a value of a: 10
# Enter a value of b: 5
# add= 15
#  sub= 5
#  mult= 50
#  div= 2.0
#  exp= 100000

# %%
import math
a = float(input("enter the radius: "))
print(f"area of circle = {math.pi*a*a}")
# Out:
# enter the radius: 5
# area of circle = 78.53981633974483

# %%
import math
a = float(input("Enter a nummber: "))
print(f"answer = {math.log10(a)}")
# Out:
# Enter a nummber: 10
# answer = 1.0

# %%
import math
print(f"answer = {math.sin(math.pi/3)}")
# Out:
# answer = 0.8660254037844386

# %%
a = 10
b = 5
if a > b:
  print(f"a is greater than b")

else:
  print(f"b is greater than a")
# Out:
# a is greater than b

# %%
a = int(input("Enter a value of a: ",))
b = int(input("Enter a value of b: "))
if a > b:
  print(f"a is greater than b")

else:
  print(f"b is greater than a")
# Out:
# Enter a value of a: 6
# Enter a value of b: 12
# b is greater than a
